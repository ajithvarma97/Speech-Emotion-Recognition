# %%
import librosa
import soundfile
import os, glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding
from keras.utils.np_utils import to_categorical
from tensorflow.keras.layers import Input, Flatten, Dropout, Activation
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop

# %%
def extract_feature(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result=np.hstack((result, mel))
    return result

# %%
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

#DataFlair - Emotions to observe
observed_emotions=['calm', 'happy', 'fearful', 'disgust']

# %%
def load_data(test_size=0.2):
    x,y=[],[]
    for file in glob.glob("C:\\Speech Emotion\\RAVESS\\Actor_*\\*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(int(file_name[7:8]) - 1)
    return train_test_split(np.array(x), y, test_size=test_size, random_state=9)

# %%
x_train,x_test,y_train,y_test=load_data(test_size=0.25)

# %%
x_traincnn = np.expand_dims(x_train, axis=2)
x_testcnn = np.expand_dims(x_test, axis=2)

# %%
model1=Sequential()

# %%
model1.add(Conv1D(16, 7,padding='same',strides=2,
                 input_shape=(180,1)))
model1.add(Activation('relu'))
model1.add(Conv1D(32, 5,padding='same',strides=2 ,))
model1.add(Activation('relu'))
model1.add(Conv1D(64, 3,padding='same',strides=2 ,))
model1.add(Activation('relu'))
model1.add(Conv1D(128, 3,padding='same',strides=2 ,))
model1.add(Activation('relu'))
model1.add(Conv1D(128, 3,padding='same',strides=2 ,))
model1.add(Activation('relu'))
model1.add(Dropout(0.25))
model1.add(Flatten())
model1.add(Dense(512))
model1.add(Dense(8))
model1.add(Activation('softmax'))
opt1 = RMSprop(lr=0.00005, rho=0.9, epsilon=None, decay=0.0)
# Out:
# C:\Users\ajithvarma\anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 90, 16)            128
# _________________________________________________________________
# activation (Activation)      (None, 90, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 45, 32)            2592
# _________________________________________________________________
# activation_1 (Activation)    (None, 45, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 23, 64)            6208
# _________________________________________________________________
# activation_2 (Activation)    (None, 23, 64)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 12, 128)           24704
# _________________________________________________________________
# activation_3 (Activation)    (None, 12, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 6, 128)            49280
# _________________________________________________________________
# activation_4 (Activation)    (None, 6, 128)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 128)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 768)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               393728
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 4104
# _________________________________________________________________
# activation_5 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 480,744
# Trainable params: 480,744
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt1,
              metrics=['accuracy'])

# %%
from keras import callbacks
x_traincnn = np.asarray(x_traincnn)
y_train = np.asarray(y_train)
x_testcnn = np.asarray(x_testcnn)
y_test = np.asarray(y_test)

cnnhistory=model1.fit(x_traincnn, y_train, batch_size=16, epochs=220, validation_data=(x_testcnn, y_test))
# Out:
# Epoch 1/220
# 36/36 [==============================] - 2s 23ms/step - loss: 1.6590 - accuracy: 0.2639 - val_loss: 1.3793 - val_accuracy: 0.3646
# Epoch 2/220
# 36/36 [==============================] - 1s 18ms/step - loss: 1.4572 - accuracy: 0.2812 - val_loss: 1.3236 - val_accuracy: 0.3177
# Epoch 3/220
# 36/36 [==============================] - 1s 17ms/step - loss: 1.3806 - accuracy: 0.3229 - val_loss: 1.3200 - val_accuracy: 0.3958
# Epoch 4/220
# 36/36 [==============================] - 1s 17ms/step - loss: 1.3433 - accuracy: 0.3403 - val_loss: 1.2696 - val_accuracy: 0.3906
# Epoch 5/220
# 36/36 [==============================] - 1s 14ms/step - loss: 1.2781 - accuracy: 0.4045 - val_loss: 1.2546 - val_accuracy: 0.4167
# Epoch 6/220
# 36/36 [==============================] - 1s 15ms/step - loss: 1.2704 - accuracy: 0.3941 - val_loss: 1.2131 - val_accuracy: 0.5104
# Epoch 7/220
# 36/36 [==============================] - 1s 16ms/step - loss: 1.2205 - accuracy: 0.4184 - val_loss: 1.2315 - val_accuracy: 0.3438
# Epoch 8/220
# 36/36 [==============================] - 1s 17ms/step - loss: 1.2044 - accuracy: 0.4271 - val_loss: 1.2092 - val_accuracy: 0.3802
# Epoch 9/220
# 36/36 [==============================] - 1s 18ms/step - loss: 1.1784 - accuracy: 0.4479 - val_loss: 1.1734 - val_accuracy: 0.4844
# Epoch 10/220
# 36/36 [==============================] - 1s 16ms/step - loss: 1.1704 - accuracy: 0.4583 - val_loss: 1.1436 - val_accuracy: 0.4583
# Epoch 11/220
# 36/36 [==============================] - 1s 20ms/step - loss: 1.1426 - accuracy: 0.4653 - val_loss: 1.1773 - val_accuracy: 0.3958
# Epoch 12/220
# 36/36 [==============================] - 1s 16ms/step - loss: 1.1295 - accuracy: 0.4896 - val_loss: 1.1412 - val_accuracy: 0.5417
# Epoch 13/220
# 36/36 [==============================] - 1s 16ms/step - loss: 1.0961 - accuracy: 0.5017 - val_loss: 1.1605 - val_accuracy: 0.5365
# Epoch 14/220
# 36/36 [==============================] - 1s 18ms/step - loss: 1.0989 - accuracy: 0.4913 - val_loss: 1.1261 - val_accuracy: 0.5208
# Epoch 15/220
# 36/36 [==============================] - 1s 17ms/step - loss: 1.0743 - accuracy: 0.5156 - val_loss: 1.1345 - val_accuracy: 0.5312
# Epoch 16/220
# 36/36 [==============================] - 0s 13ms/step - loss: 1.0618 - accuracy: 0.4983 - val_loss: 1.0931 - val_accuracy: 0.5833
# Epoch 17/220
# 36/36 [==============================] - 0s 12ms/step - loss: 1.0486 - accuracy: 0.5243 - val_loss: 1.0882 - val_accuracy: 0.5208
# Epoch 18/220
# 36/36 [==============================] - 0s 13ms/step - loss: 1.0389 - accuracy: 0.5208 - val_loss: 1.0652 - val_accuracy: 0.5469
# Epoch 19/220
# 36/36 [==============================] - 0s 12ms/step - loss: 1.0237 - accuracy: 0.5382 - val_loss: 1.0836 - val_accuracy: 0.5521
# Epoch 20/220
# 36/36 [==============================] - 0s 12ms/step - loss: 1.0110 - accuracy: 0.5521 - val_loss: 1.1261 - val_accuracy: 0.5312
# Epoch 21/220
# 36/36 [==============================] - 0s 13ms/step - loss: 1.0012 - accuracy: 0.5694 - val_loss: 1.0608 - val_accuracy: 0.5365
# Epoch 22/220
# 36/36 [==============================] - 0s 13ms/step - loss: 1.0001 - accuracy: 0.5712 - val_loss: 1.0379 - val_accuracy: 0.5417
# Epoch 23/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.9702 - accuracy: 0.5885 - val_loss: 1.0273 - val_accuracy: 0.5156
# Epoch 24/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.9631 - accuracy: 0.6007 - val_loss: 1.0404 - val_accuracy: 0.5469
# Epoch 25/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.9422 - accuracy: 0.6076 - val_loss: 1.0560 - val_accuracy: 0.5938
# Epoch 26/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.9498 - accuracy: 0.6007 - val_loss: 0.9929 - val_accuracy: 0.6042
# Epoch 27/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.9411 - accuracy: 0.5990 - val_loss: 0.9944 - val_accuracy: 0.5938
# Epoch 28/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.9229 - accuracy: 0.6354 - val_loss: 1.0375 - val_accuracy: 0.5729
# Epoch 29/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.9166 - accuracy: 0.6215 - val_loss: 0.9699 - val_accuracy: 0.6146
# Epoch 30/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8973 - accuracy: 0.6285 - val_loss: 1.0031 - val_accuracy: 0.5312
# Epoch 31/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8700 - accuracy: 0.6580 - val_loss: 0.9597 - val_accuracy: 0.5729
# Epoch 32/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8590 - accuracy: 0.6458 - val_loss: 0.9614 - val_accuracy: 0.5938
# Epoch 33/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8831 - accuracy: 0.6372 - val_loss: 0.9549 - val_accuracy: 0.6094
# Epoch 34/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8486 - accuracy: 0.6458 - val_loss: 0.9477 - val_accuracy: 0.6146
# Epoch 35/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8493 - accuracy: 0.6684 - val_loss: 0.9305 - val_accuracy: 0.6146
# Epoch 36/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8303 - accuracy: 0.6684 - val_loss: 0.9650 - val_accuracy: 0.5729
# Epoch 37/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8309 - accuracy: 0.6892 - val_loss: 0.9390 - val_accuracy: 0.6250
# Epoch 38/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8247 - accuracy: 0.6649 - val_loss: 0.9897 - val_accuracy: 0.5469
# Epoch 39/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8284 - accuracy: 0.6632 - val_loss: 0.9071 - val_accuracy: 0.6302
# Epoch 40/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7955 - accuracy: 0.6719 - val_loss: 0.9296 - val_accuracy: 0.6198
# Epoch 41/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7947 - accuracy: 0.6892 - val_loss: 0.9211 - val_accuracy: 0.6250
# Epoch 42/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7777 - accuracy: 0.7135 - val_loss: 0.9503 - val_accuracy: 0.6094
# Epoch 43/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7637 - accuracy: 0.7066 - val_loss: 0.8939 - val_accuracy: 0.6250
# Epoch 44/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7707 - accuracy: 0.7049 - val_loss: 0.8827 - val_accuracy: 0.6406
# Epoch 45/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7461 - accuracy: 0.7066 - val_loss: 0.9227 - val_accuracy: 0.6042
# Epoch 46/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7482 - accuracy: 0.7170 - val_loss: 0.8773 - val_accuracy: 0.6458
# Epoch 47/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7215 - accuracy: 0.7465 - val_loss: 0.8737 - val_accuracy: 0.6250
# Epoch 48/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7159 - accuracy: 0.7292 - val_loss: 0.8784 - val_accuracy: 0.6354
# Epoch 49/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7152 - accuracy: 0.7378 - val_loss: 0.8814 - val_accuracy: 0.6354
# Epoch 50/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7141 - accuracy: 0.7101 - val_loss: 0.8907 - val_accuracy: 0.6354
# Epoch 51/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6917 - accuracy: 0.7309 - val_loss: 0.9015 - val_accuracy: 0.5729
# Epoch 52/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.6899 - accuracy: 0.7396 - val_loss: 0.8705 - val_accuracy: 0.6615
# Epoch 53/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.6851 - accuracy: 0.7413 - val_loss: 0.8635 - val_accuracy: 0.6458
# Epoch 54/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.6721 - accuracy: 0.7292 - val_loss: 0.8882 - val_accuracy: 0.6458
# Epoch 55/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6640 - accuracy: 0.7361 - val_loss: 0.8805 - val_accuracy: 0.6406
# Epoch 56/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.6579 - accuracy: 0.7483 - val_loss: 0.9008 - val_accuracy: 0.6719
# Epoch 57/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6397 - accuracy: 0.7691 - val_loss: 0.8525 - val_accuracy: 0.6302
# Epoch 58/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6368 - accuracy: 0.7396 - val_loss: 0.9057 - val_accuracy: 0.6719
# Epoch 59/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6023 - accuracy: 0.7743 - val_loss: 0.8375 - val_accuracy: 0.6250
# Epoch 60/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6108 - accuracy: 0.7656 - val_loss: 0.8478 - val_accuracy: 0.6510
# Epoch 61/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6278 - accuracy: 0.7500 - val_loss: 0.8373 - val_accuracy: 0.6562
# Epoch 62/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6101 - accuracy: 0.7639 - val_loss: 0.8368 - val_accuracy: 0.6458
# Epoch 63/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6020 - accuracy: 0.7691 - val_loss: 0.8292 - val_accuracy: 0.6562
# Epoch 64/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6149 - accuracy: 0.7500 - val_loss: 0.8700 - val_accuracy: 0.6250
# Epoch 65/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.5954 - accuracy: 0.7552 - val_loss: 0.8594 - val_accuracy: 0.6198
# Epoch 66/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.5789 - accuracy: 0.7917 - val_loss: 0.8332 - val_accuracy: 0.6615
# Epoch 67/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.5509 - accuracy: 0.7865 - val_loss: 0.8310 - val_accuracy: 0.6667
# Epoch 68/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.5543 - accuracy: 0.7934 - val_loss: 0.8685 - val_accuracy: 0.6198
# Epoch 69/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.5413 - accuracy: 0.7951 - val_loss: 0.8374 - val_accuracy: 0.6615
# Epoch 70/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.5475 - accuracy: 0.8003 - val_loss: 0.8597 - val_accuracy: 0.6667
# Epoch 71/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.5332 - accuracy: 0.7934 - val_loss: 0.8620 - val_accuracy: 0.6146
# Epoch 72/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.5251 - accuracy: 0.8073 - val_loss: 0.8992 - val_accuracy: 0.6198
# Epoch 73/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.5271 - accuracy: 0.8056 - val_loss: 0.8289 - val_accuracy: 0.6562
# Epoch 74/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.5129 - accuracy: 0.8021 - val_loss: 0.8413 - val_accuracy: 0.6667
# Epoch 75/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4934 - accuracy: 0.8142 - val_loss: 0.8964 - val_accuracy: 0.6250
# Epoch 76/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.5051 - accuracy: 0.8090 - val_loss: 0.8442 - val_accuracy: 0.6562
# Epoch 77/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.4723 - accuracy: 0.8194 - val_loss: 0.8335 - val_accuracy: 0.6510
# Epoch 78/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4845 - accuracy: 0.8229 - val_loss: 0.8472 - val_accuracy: 0.6510
# Epoch 79/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4872 - accuracy: 0.8003 - val_loss: 0.8645 - val_accuracy: 0.6510
# Epoch 80/220
# 36/36 [==============================] - 0s 14ms/step - loss: 0.4630 - accuracy: 0.8299 - val_loss: 0.8662 - val_accuracy: 0.6510
# Epoch 81/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4800 - accuracy: 0.8385 - val_loss: 0.8428 - val_accuracy: 0.6250
# Epoch 82/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.4509 - accuracy: 0.8281 - val_loss: 0.8186 - val_accuracy: 0.6562
# Epoch 83/220
# 36/36 [==============================] - 1s 17ms/step - loss: 0.4623 - accuracy: 0.8212 - val_loss: 0.8322 - val_accuracy: 0.6562
# Epoch 84/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4440 - accuracy: 0.8420 - val_loss: 0.8324 - val_accuracy: 0.6667
# Epoch 85/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4367 - accuracy: 0.8403 - val_loss: 0.8803 - val_accuracy: 0.6302
# Epoch 86/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4422 - accuracy: 0.8368 - val_loss: 0.8525 - val_accuracy: 0.6615
# Epoch 87/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4296 - accuracy: 0.8403 - val_loss: 0.8556 - val_accuracy: 0.6615
# Epoch 88/220
# 36/36 [==============================] - 0s 14ms/step - loss: 0.4434 - accuracy: 0.8177 - val_loss: 0.8229 - val_accuracy: 0.6667
# Epoch 89/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4146 - accuracy: 0.8316 - val_loss: 0.8330 - val_accuracy: 0.6510
# Epoch 90/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4133 - accuracy: 0.8472 - val_loss: 0.8388 - val_accuracy: 0.6823
# Epoch 91/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4218 - accuracy: 0.8368 - val_loss: 0.8819 - val_accuracy: 0.6146
# Epoch 92/220
# 36/36 [==============================] - 1s 13ms/step - loss: 0.3964 - accuracy: 0.8524 - val_loss: 0.8407 - val_accuracy: 0.6146
# Epoch 93/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3990 - accuracy: 0.8559 - val_loss: 0.8128 - val_accuracy: 0.6562
# Epoch 94/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4016 - accuracy: 0.8611 - val_loss: 0.7928 - val_accuracy: 0.6979
# Epoch 95/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3787 - accuracy: 0.8611 - val_loss: 0.8460 - val_accuracy: 0.6667
# Epoch 96/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.3815 - accuracy: 0.8663 - val_loss: 0.8088 - val_accuracy: 0.6667
# Epoch 97/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.3934 - accuracy: 0.8594 - val_loss: 0.9062 - val_accuracy: 0.6250
# Epoch 98/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3673 - accuracy: 0.8646 - val_loss: 0.8762 - val_accuracy: 0.6094
# Epoch 99/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.3539 - accuracy: 0.8889 - val_loss: 0.8398 - val_accuracy: 0.6510
# Epoch 100/220
# 36/36 [==============================] - 0s 14ms/step - loss: 0.3767 - accuracy: 0.8490 - val_loss: 0.8284 - val_accuracy: 0.6615
# Epoch 101/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3189 - accuracy: 0.8958 - val_loss: 0.8548 - val_accuracy: 0.6562
# Epoch 102/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.3465 - accuracy: 0.8767 - val_loss: 0.8720 - val_accuracy: 0.6302
# Epoch 103/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.3403 - accuracy: 0.8767 - val_loss: 0.8276 - val_accuracy: 0.6667
# Epoch 104/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3475 - accuracy: 0.8785 - val_loss: 0.8550 - val_accuracy: 0.6510
# Epoch 105/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.3026 - accuracy: 0.8889 - val_loss: 0.8836 - val_accuracy: 0.6562
# Epoch 106/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3093 - accuracy: 0.9010 - val_loss: 0.8123 - val_accuracy: 0.6979
# Epoch 107/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.3117 - accuracy: 0.8941 - val_loss: 0.8392 - val_accuracy: 0.6927
# Epoch 108/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.3188 - accuracy: 0.8906 - val_loss: 0.8177 - val_accuracy: 0.6771
# Epoch 109/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3033 - accuracy: 0.8993 - val_loss: 0.8109 - val_accuracy: 0.6562
# Epoch 110/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.2924 - accuracy: 0.8976 - val_loss: 0.8297 - val_accuracy: 0.6927
# Epoch 111/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3127 - accuracy: 0.8906 - val_loss: 0.8315 - val_accuracy: 0.6771
# Epoch 112/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.2963 - accuracy: 0.8976 - val_loss: 0.9740 - val_accuracy: 0.6406
# Epoch 113/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3008 - accuracy: 0.8889 - val_loss: 0.8975 - val_accuracy: 0.6615
# Epoch 114/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.2701 - accuracy: 0.9167 - val_loss: 0.9365 - val_accuracy: 0.6406
# Epoch 115/220
# 36/36 [==============================] - 0s 14ms/step - loss: 0.2641 - accuracy: 0.9097 - val_loss: 0.8371 - val_accuracy: 0.6823
# Epoch 116/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2754 - accuracy: 0.9045 - val_loss: 0.8711 - val_accuracy: 0.6302
# Epoch 117/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2764 - accuracy: 0.9028 - val_loss: 0.8518 - val_accuracy: 0.6458
# Epoch 118/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.2476 - accuracy: 0.9271 - val_loss: 0.8789 - val_accuracy: 0.6667
# Epoch 119/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2835 - accuracy: 0.8958 - val_loss: 0.8173 - val_accuracy: 0.6823
# Epoch 120/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.2485 - accuracy: 0.9184 - val_loss: 0.8223 - val_accuracy: 0.6927
# Epoch 121/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2448 - accuracy: 0.9097 - val_loss: 0.8616 - val_accuracy: 0.6667
# Epoch 122/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2169 - accuracy: 0.9392 - val_loss: 0.9052 - val_accuracy: 0.6615
# Epoch 123/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.2232 - accuracy: 0.9306 - val_loss: 0.8345 - val_accuracy: 0.6875
# Epoch 124/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2252 - accuracy: 0.9392 - val_loss: 0.9848 - val_accuracy: 0.6562
# Epoch 125/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.2248 - accuracy: 0.9236 - val_loss: 0.8404 - val_accuracy: 0.6771
# Epoch 126/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2157 - accuracy: 0.9271 - val_loss: 0.8453 - val_accuracy: 0.6875
# Epoch 127/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2160 - accuracy: 0.9306 - val_loss: 0.8573 - val_accuracy: 0.6823
# Epoch 128/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2311 - accuracy: 0.9253 - val_loss: 0.8710 - val_accuracy: 0.6875
# Epoch 129/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.2120 - accuracy: 0.9340 - val_loss: 1.0151 - val_accuracy: 0.6250
# Epoch 130/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2112 - accuracy: 0.9288 - val_loss: 0.9085 - val_accuracy: 0.6615
# Epoch 131/220
# 36/36 [==============================] - 0s 14ms/step - loss: 0.2060 - accuracy: 0.9375 - val_loss: 0.8714 - val_accuracy: 0.6615
# Epoch 132/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1954 - accuracy: 0.9288 - val_loss: 0.8500 - val_accuracy: 0.6771
# Epoch 133/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.1962 - accuracy: 0.9392 - val_loss: 0.8588 - val_accuracy: 0.6823
# Epoch 134/220
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1931 - accuracy: 0.9306 - val_loss: 0.8582 - val_accuracy: 0.6875
# Epoch 135/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1905 - accuracy: 0.9514 - val_loss: 0.9061 - val_accuracy: 0.6719
# Epoch 136/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1891 - accuracy: 0.9323 - val_loss: 0.9019 - val_accuracy: 0.6719
# Epoch 137/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.1725 - accuracy: 0.9444 - val_loss: 1.0258 - val_accuracy: 0.6458
# Epoch 138/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1802 - accuracy: 0.9410 - val_loss: 0.9108 - val_accuracy: 0.6771
# Epoch 139/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.1750 - accuracy: 0.9410 - val_loss: 0.9190 - val_accuracy: 0.6823
# Epoch 140/220
# 36/36 [==============================] - 1s 17ms/step - loss: 0.1649 - accuracy: 0.9444 - val_loss: 0.9039 - val_accuracy: 0.6875
# Epoch 141/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.1779 - accuracy: 0.9375 - val_loss: 0.9380 - val_accuracy: 0.6823
# Epoch 142/220
# 36/36 [==============================] - 1s 17ms/step - loss: 0.1692 - accuracy: 0.9514 - val_loss: 0.9450 - val_accuracy: 0.6875
# Epoch 143/220
# 36/36 [==============================] - 1s 17ms/step - loss: 0.1530 - accuracy: 0.9583 - val_loss: 0.9030 - val_accuracy: 0.6875
# Epoch 144/220
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1864 - accuracy: 0.9288 - val_loss: 0.9163 - val_accuracy: 0.6823
# Epoch 145/220
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1587 - accuracy: 0.9566 - val_loss: 0.8728 - val_accuracy: 0.6823
# Epoch 146/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1413 - accuracy: 0.9653 - val_loss: 0.8960 - val_accuracy: 0.6719
# Epoch 147/220
# 36/36 [==============================] - 0s 14ms/step - loss: 0.1617 - accuracy: 0.9410 - val_loss: 0.9073 - val_accuracy: 0.6771
# Epoch 148/220
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1465 - accuracy: 0.9583 - val_loss: 0.9029 - val_accuracy: 0.6875
# Epoch 149/220
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1256 - accuracy: 0.9670 - val_loss: 0.9061 - val_accuracy: 0.6823
# Epoch 150/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.1491 - accuracy: 0.9514 - val_loss: 0.9582 - val_accuracy: 0.6458
# Epoch 151/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1431 - accuracy: 0.9688 - val_loss: 0.9351 - val_accuracy: 0.6667
# Epoch 152/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.1183 - accuracy: 0.9688 - val_loss: 0.9878 - val_accuracy: 0.6771
# Epoch 153/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1315 - accuracy: 0.9635 - val_loss: 0.9540 - val_accuracy: 0.6615
# Epoch 154/220
# 36/36 [==============================] - 1s 15ms/step - loss: 0.1223 - accuracy: 0.9653 - val_loss: 0.9758 - val_accuracy: 0.6667
# Epoch 155/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.1284 - accuracy: 0.9705 - val_loss: 0.9068 - val_accuracy: 0.6979
# Epoch 156/220
# 36/36 [==============================] - 1s 14ms/step - loss: 0.1564 - accuracy: 0.9583 - val_loss: 0.9575 - val_accuracy: 0.6719
# Epoch 157/220
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1403 - accuracy: 0.9601 - val_loss: 0.9385 - val_accuracy: 0.6927
# Epoch 158/220
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0935 - accuracy: 0.9792 - val_loss: 0.9702 - val_accuracy: 0.6719
# Epoch 159/220
# 36/36 [==============================] - 0s 14ms/step - loss: 0.1118 - accuracy: 0.9670 - val_loss: 0.9199 - val_accuracy: 0.6875
# Epoch 160/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.1017 - accuracy: 0.9792 - val_loss: 0.9143 - val_accuracy: 0.7083
# Epoch 161/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.1067 - accuracy: 0.9740 - val_loss: 0.9142 - val_accuracy: 0.6875
# Epoch 162/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1117 - accuracy: 0.9740 - val_loss: 0.9826 - val_accuracy: 0.6927
# Epoch 163/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1186 - accuracy: 0.9722 - val_loss: 0.9763 - val_accuracy: 0.6979
# Epoch 164/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.1078 - accuracy: 0.9705 - val_loss: 1.0267 - val_accuracy: 0.6615
# Epoch 165/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0987 - accuracy: 0.9792 - val_loss: 0.9562 - val_accuracy: 0.6927
# Epoch 166/220
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0926 - accuracy: 0.9740 - val_loss: 0.9557 - val_accuracy: 0.6719
# Epoch 167/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.1146 - accuracy: 0.9566 - val_loss: 1.0064 - val_accuracy: 0.6823
# Epoch 168/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0865 - accuracy: 0.9774 - val_loss: 0.9575 - val_accuracy: 0.6823
# Epoch 169/220
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0862 - accuracy: 0.9826 - val_loss: 1.0500 - val_accuracy: 0.6615
# Epoch 170/220
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0852 - accuracy: 0.9878 - val_loss: 0.9525 - val_accuracy: 0.7031
# Epoch 171/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0859 - accuracy: 0.9826 - val_loss: 1.0311 - val_accuracy: 0.6510
# Epoch 172/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0738 - accuracy: 0.9878 - val_loss: 0.9980 - val_accuracy: 0.7083
# Epoch 173/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0943 - accuracy: 0.9740 - val_loss: 1.0178 - val_accuracy: 0.6771
# Epoch 174/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0876 - accuracy: 0.9757 - val_loss: 1.0913 - val_accuracy: 0.6667
# Epoch 175/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0795 - accuracy: 0.9792 - val_loss: 1.0346 - val_accuracy: 0.6875
# Epoch 176/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0912 - accuracy: 0.9792 - val_loss: 0.9951 - val_accuracy: 0.7135
# Epoch 177/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0601 - accuracy: 0.9948 - val_loss: 1.0836 - val_accuracy: 0.7031
# Epoch 178/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0815 - accuracy: 0.9844 - val_loss: 1.1157 - val_accuracy: 0.6875
# Epoch 179/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0894 - accuracy: 0.9896 - val_loss: 0.9925 - val_accuracy: 0.7188
# Epoch 180/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0618 - accuracy: 0.9861 - val_loss: 1.1949 - val_accuracy: 0.6771
# Epoch 181/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0734 - accuracy: 0.9792 - val_loss: 1.0580 - val_accuracy: 0.7031
# Epoch 182/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0691 - accuracy: 0.9861 - val_loss: 1.0850 - val_accuracy: 0.6719
# Epoch 183/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0639 - accuracy: 0.9878 - val_loss: 1.0731 - val_accuracy: 0.7031
# Epoch 184/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0826 - accuracy: 0.9757 - val_loss: 1.0444 - val_accuracy: 0.6927
# Epoch 185/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0671 - accuracy: 0.9844 - val_loss: 1.0734 - val_accuracy: 0.6979
# Epoch 186/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0649 - accuracy: 0.9809 - val_loss: 1.1479 - val_accuracy: 0.6823
# Epoch 187/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0568 - accuracy: 0.9878 - val_loss: 1.1692 - val_accuracy: 0.6875
# Epoch 188/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0537 - accuracy: 0.9913 - val_loss: 1.1306 - val_accuracy: 0.6875
# Epoch 189/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0640 - accuracy: 0.9792 - val_loss: 1.1079 - val_accuracy: 0.6927
# Epoch 190/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0592 - accuracy: 0.9861 - val_loss: 1.0979 - val_accuracy: 0.7031
# Epoch 191/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0530 - accuracy: 0.9896 - val_loss: 1.3572 - val_accuracy: 0.6719
# Epoch 192/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0560 - accuracy: 0.9792 - val_loss: 1.0996 - val_accuracy: 0.6875
# Epoch 193/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0639 - accuracy: 0.9844 - val_loss: 1.0969 - val_accuracy: 0.7031
# Epoch 194/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0497 - accuracy: 0.9878 - val_loss: 1.2975 - val_accuracy: 0.6510
# Epoch 195/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0439 - accuracy: 0.9913 - val_loss: 1.0930 - val_accuracy: 0.6927
# Epoch 196/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0537 - accuracy: 0.9844 - val_loss: 1.0986 - val_accuracy: 0.6979
# Epoch 197/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0515 - accuracy: 0.9931 - val_loss: 1.1996 - val_accuracy: 0.6615
# Epoch 198/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0507 - accuracy: 0.9861 - val_loss: 1.0996 - val_accuracy: 0.6927
# Epoch 199/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0610 - accuracy: 0.9774 - val_loss: 1.0918 - val_accuracy: 0.6875
# Epoch 200/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0505 - accuracy: 0.9861 - val_loss: 1.0950 - val_accuracy: 0.6823
# Epoch 201/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0489 - accuracy: 0.9878 - val_loss: 1.0996 - val_accuracy: 0.6823
# Epoch 202/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0438 - accuracy: 0.9931 - val_loss: 1.1846 - val_accuracy: 0.6823
# Epoch 203/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0450 - accuracy: 0.9878 - val_loss: 1.1302 - val_accuracy: 0.7083
# Epoch 204/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0411 - accuracy: 0.9931 - val_loss: 1.1459 - val_accuracy: 0.7031
# Epoch 205/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0512 - accuracy: 0.9931 - val_loss: 1.1229 - val_accuracy: 0.7135
# Epoch 206/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0402 - accuracy: 0.9913 - val_loss: 1.1417 - val_accuracy: 0.6875
# Epoch 207/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0461 - accuracy: 0.9896 - val_loss: 1.2205 - val_accuracy: 0.6927
# Epoch 208/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0383 - accuracy: 0.9913 - val_loss: 1.2282 - val_accuracy: 0.6875
# Epoch 209/220
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0355 - accuracy: 0.9965 - val_loss: 1.3021 - val_accuracy: 0.6875
# Epoch 210/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0366 - accuracy: 0.9896 - val_loss: 1.1287 - val_accuracy: 0.6979
# Epoch 211/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0405 - accuracy: 0.9913 - val_loss: 1.1709 - val_accuracy: 0.6979
# Epoch 212/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0386 - accuracy: 0.9913 - val_loss: 1.2464 - val_accuracy: 0.6927
# Epoch 213/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0357 - accuracy: 0.9896 - val_loss: 1.1885 - val_accuracy: 0.6979
# Epoch 214/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0296 - accuracy: 0.9983 - val_loss: 1.2750 - val_accuracy: 0.6875
# Epoch 215/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0350 - accuracy: 0.9878 - val_loss: 1.2715 - val_accuracy: 0.6823
# Epoch 216/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0356 - accuracy: 0.9878 - val_loss: 1.3443 - val_accuracy: 0.6667
# Epoch 217/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0398 - accuracy: 0.9896 - val_loss: 1.1961 - val_accuracy: 0.6927
# Epoch 218/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0373 - accuracy: 0.9913 - val_loss: 1.4410 - val_accuracy: 0.7031
# Epoch 219/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0274 - accuracy: 0.9913 - val_loss: 1.1241 - val_accuracy: 0.7344
# Epoch 220/220
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0236 - accuracy: 0.9983 - val_loss: 1.2915 - val_accuracy: 0.6979

# %%
plt.plot(cnnhistory.history['accuracy'])
plt.plot(cnnhistory.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
predictions = model1.predict_classes(x_testcnn)
new_Ytest = y_test.astype(int)
report = classification_report(new_Ytest, predictions)
print(report)
# Out:
# C:\Users\ajithvarma\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            1       0.84      0.81      0.82        57
#            2       0.63      0.72      0.67        50
#            5       0.53      0.65      0.59        37
#            6       0.80      0.58      0.67        48
#
#     accuracy                           0.70       192
#    macro avg       0.70      0.69      0.69       192
# weighted avg       0.72      0.70      0.70       192

# %%
model_name = 'Emotion_Voice_Detection_CNN.h5'
save_dir = '/Speech Emotion'
# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model1.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at /Speech Emotion\Emotion_Voice_Detection_CNN.h5
